# %% [markdown]
# <a href="https://colab.research.google.com/github/Emily7464/NLP_2025/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
_Myname='samejang'
my_name='홍길동'
MyName3='Honggil-dong'
country='대한민국'

# %%
1_str='안녕하세요 파이썬!'
File"<stdin>",1ine1
1_str='안녕하세요 파이썬!'
# Out:
#   File "/tmp/ipython-input-447739497.py", line 1
#     1_str='안녕하세요 파이썬!'
#      ^
# SyntaxError: invalid decimal literal

# %%
_%var='Temp Variables'
@address='samsjang@naver.com'
# Out:
#   File "/tmp/ipython-input-2394323943.py", line 1
#     _%var='Temp Variables'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
counter=1
Coounter=2

# %%
and=1
File"<stdin">,line1
and=1
# Out:
#   File "/tmp/ipython-input-1525551810.py", line 1
#     and=1
#     ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist
['False','None','True','and','as','assert','async','await','break','class','contin
ue','def','del','elif','else','except','finally','for','from','gopbal','if','import']
# Out:
#   File "/tmp/ipython-input-1203849442.py", line 3
#     ['False','None','True','and','as','assert','async','await','break','class','contin
#                                                                                ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
abs=1
abs(-1)
Traceback(mostrecentcalllast):
File"<stadin>",line1,in<module>
# Out:
#   File "/tmp/ipython-input-2172999514.py", line 3
#     Traceback(mostrecentcalllast):
#                                  ^
# SyntaxError: invalid syntax

# %%
intData=1
pi=3.14

# %%
flag=True

# %%
ch='x'
strData='사랑해요 파이썬!'

# %%
 buffer=1
 buffer+2
# Out:
# 3

# %%
buffer='three'
buffer
# Out:
# 'three'

# %%
a=1
b=5
print(a+b)
# Out:
# 6

# %%
comment='Result='
"""a=1
b=100
print(a+b)"""
a=5
b=50
print(comment,a+b)
# Out:
# Result= 55
